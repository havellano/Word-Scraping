# %% [markdown]
# Lab 06 - [Hadrian] [Avellano]

# %% [markdown]
# Date - [May] [03] 2023

# %% [markdown]
# Howdy hey coyotay!🐺
#
# If you haven't already please go watch the lecture(s) from modules 4 (RegEx) and 6 (Web Scraping).
#
# In this week's lab you will be taking on the role of a student who decided to wait last minute to write his/hers research paper for science class...uh oh. The paper is due at midnight and it is currently 10:02pm.
#
# To get this assignment turned in on time you will need to:
# 1. Perform webscraping on the following wikipedia webpage on various volcanic eruptions:
#    https://en.wikipedia.org/wiki/Types_of_volcanic_eruptions
#
# 2. Extract the sections on the following types of volcanic eruptions:
#    - Surtseyan
#    - Submarine
#    - Subglacial
#
# 3. Print these sections using the print() function
#
# Uh oh...you realized you will get in big trouble for plagiarizing...
#
# 4. Use RegEx to change 5 sentences in each paragraph.
#
# Bet you won't get caught now 😉
#
# 5. Write these modified paragraphs to a text file using Python
# ----------------------------------------------------------------------------------|
#
# What to turn in:
# - Completed Python notebook (Make sure that your notebook shows output for each cell)
# - Text file containing the modified paragraphs from step 4

# %% [markdown]
# Write your code below ⬇️

# %%
#1) 
import requests
from bs4 import BeautifulSoup

url = 'https://en.wikipedia.org/wiki/Types_of_volcanic_eruptions'
response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')
soup
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-language-alert-in-sidebar-enabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-enabled vector-feature-main-menu-pinned-disabled vector-feature-limited-width-enabled vector-feature-limited-width-content-enabled vector-feature-zebra-design-disabled" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Types of volcanic eruptions - Wikipedia
#   </title>
#   <script>
# ...

# %%
print(soup.get_text())
# Out:
# Types of volcanic eruptions - Wikipedia
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Jump to content
#
#
#
#
#
#
#
#
# Main menu
#
#
#
#
#
# Main menu
# move to sidebar
# hide
#
#
#
# 		Navigation
#
#
# Main pageContentsCurrent eventsRandom articleAbout WikipediaContact usDonate
#
#
#
#
# 		Contribute
#
#
# HelpLearn to editCommunity portalRecent changesUpload file
#
#
#
#
# Languages
#
# Language links are at the top of the page across from the title.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Search
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Create accountLog in
#
#
#
#
#
#
# Personal tools
#
#
#
#
#  Create account Log in
#
#
#
#
# 		Pages for logged out editors learn more
#
#
# ContributionsTalk
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Contents
# move to sidebar
# hide
#
#
#
#
# (Top)
#
#
#
#
#
# 1Eruption mechanisms
#
#
# 				Toggle Eruption mechanisms subsection
#
#
#
#
#
# 1.1Volcanic explosivity index
#
#
#
#
#
#
#
#
#
# 2Magmatic eruptions
#
#
# ...

# %%
#2)
Sur = soup.find('span', {'id': 'Surtseyan'}).find_next('p')
Sub = soup.find('span', {'id': 'Submarine'}).find_next('p')
Subg = soup.find('span', {'id': 'Subglacial'}).find_next('p')

# %%
#3)
print(Sur.text)
print(Sub.text)
print(Subg.text)
# Out:
# A Surtseyan (or hydrovolcanic) eruption is a type of volcanic eruption characterized by shallow-water interactions between water and lava, named after its most famous example, the eruption and formation of the island of Surtsey off the coast of Iceland in 1963. Surtseyan eruptions are the "wet" equivalent of ground-based Strombolian eruptions, but because they take place in water they are much more explosive. As water is heated by lava, it flashes into steam and expands violently, fragmenting the magma it contacts into fine-grained ash. Surtseyan eruptions are typical of shallow-water volcanic oceanic islands, but they are not confined to seamounts. They can happen on land as well, where rising magma that comes into contact with an aquifer (water-bearing rock formation) at shallow levels under the volcano can cause them.[51] The products of Surtseyan eruptions are generally oxidized palagonite basalts (though andesitic eruptions do occur, albeit rarely), and like Strombolian eruption
# ...

# %%
#4)
import re
modified_Sur = re.sub("eruption", "volcanic event", Sur.text, count=1)
print(modified_Sur)
# Out:
# A Surtseyan (or hydrovolcanic) volcanic event is a type of volcanic eruption characterized by shallow-water interactions between water and lava, named after its most famous example, the eruption and formation of the island of Surtsey off the coast of Iceland in 1963. Surtseyan eruptions are the "wet" equivalent of ground-based Strombolian eruptions, but because they take place in water they are much more explosive. As water is heated by lava, it flashes into steam and expands violently, fragmenting the magma it contacts into fine-grained ash. Surtseyan eruptions are typical of shallow-water volcanic oceanic islands, but they are not confined to seamounts. They can happen on land as well, where rising magma that comes into contact with an aquifer (water-bearing rock formation) at shallow levels under the volcano can cause them.[51] The products of Surtseyan eruptions are generally oxidized palagonite basalts (though andesitic eruptions do occur, albeit rarely), and like Strombolian er
# ...

# %%
#5) 
with open("volcano_paragraph.txt", "w") as f:
    f.write(modified_Sur)
    f.write("\n\n")
    f.write(Sub.text)
    f.write("\n\n")
    f.write(Subg.text)
